# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# path of data 
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# ### Yhat = a + b  X

# %% [markdown]
# ### Simple Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
x = df[['highway-mpg']]
y = df[['price']]

# %%
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
lm.predict(x)[0:5]
# Out:
# array([[16236.50464347],
#        [16236.50464347],
#        [17058.23802179],
#        [13771.3045085 ],
#        [20345.17153508]])

# %%
a = lm.intercept_
a
# Out:
# array([38423.30585816])

# %%
b = lm.coef_
b
# Out:
# array([[-821.73337832]])

# %%
y_hat =a + b * x[0:5]
y_hat
# Out:
#     highway-mpg
# 0  16236.504643
# 1  16236.504643
# 2  17058.238022
# 3  13771.304508
# 4  20345.171535

# %% [markdown]
# ### Multiple Linear regression

# %%
z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
z.head(2)
# Out:
#    horsepower  curb-weight  engine-size  highway-mpg
# 0       111.0         2548          130           27
# 1       111.0         2548          130           27

# %%
lm.fit(z,y)
# Out:
# LinearRegression()

# %%
lm.predict(z)[0:5]
# Out:
# array([[13699.11161184],
#        [13699.11161184],
#        [19051.65470233],
#        [10620.36193015],
#        [15521.31420211]])

# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48189.44347837879)

# %%
hight = 4
width = 5
plt.figure(figsize=(width,hight))
sns.regplot(x='peak-rpm',y='price',data=df)

#peak rpm
hight = 4
width = 5
plt.figure(figsize=(width,hight))
sns.regplot(x='engine-size',y='price',data=df)
plt.show()


hight = 4
width = 5
plt.figure(figsize=(width,hight))
sns.regplot(x='highway-mpg',y='price',data=df)
plt.show()

hight = 4
width = 5
plt.figure(figsize=(width,hight))
sns.regplot(x='curb-weight',y='price',data=df)
plt.show()

# %%
df[['peak-rpm','highway-mpg','curb-weight','engine-size','price']].corr()
# Out:
#              peak-rpm  highway-mpg  curb-weight  engine-size     price
# peak-rpm     1.000000    -0.058598    -0.279361    -0.256733 -0.101616
# highway-mpg -0.058598     1.000000    -0.794889    -0.679571 -0.704692
# curb-weight -0.279361    -0.794889     1.000000     0.849072  0.834415
# engine-size -0.256733    -0.679571     0.849072     1.000000  0.872335
# price       -0.101616    -0.704692     0.834415     0.872335  1.000000

# %%
hight = 4
width = 5
plt.figure(figsize=(width,hight))
sns.residplot(x='engine-size',y='price',data=df)
plt.show()

# %%
hight = 4
width = 5
plt.figure(figsize=(width,hight))
sns.residplot(x='peak-rpm',y='price',data=df)
plt.show()

hight = 4
width = 5
plt.figure(figsize=(width,hight))
sns.residplot(x='curb-weight',y='price',data=df)
plt.show()

hight = 4
width = 5
plt.figure(figsize=(width,hight))
sns.residplot(x='peak-rpm',y='price',data=df)
plt.show()


hight = 4
width = 5
plt.figure(figsize=(width,hight))
sns.residplot(x='highway-mpg',y='price',data=df)
plt.show()

# %%
height = 5
width = 7
lm.fit(z,y)
preds = lm.predict(z)

# %%
plt.figure(figsize=(width,height))

#ploting the diatibution plot...
ax1 = sns.distplot(df['price'],  hist=False, color="r",label="Actual Value")
sns.distplot(preds, hist=False, color="b", label="Fitted values", ax=ax1)
plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')
plt.show()
plt.close()
# Out:
# C:\Users\Bala Krishna Baddi\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bala Krishna Baddi\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(preds,y)
# Out:
# 2450.8013647336456

# %%
sns.regplot(x=z.sum(axis=1),y=y)
# Out:
# <AxesSubplot:ylabel='price'>

# %% [markdown]
# ### Polynomial regression

# %%
def polyplot(model,iv,dv,name):
# Out:
#   File "<ipython-input-53-c880987ba906>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %%
x = df['highway-mpg']
y = df['price']

# %%
# Here we use a polynomial of the 3rd order (cubic) 
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)

# %%
PlotPolly(p, x, y, 'highway-mpg')

# %% [markdown]
# ## Polynomial features...

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr = PolynomialFeatures(degree=2)

# %%
z_per = pr.fit_transform(z)

# %%
z.shape

# %%
z_per.shape

# %% [markdown]
# ### Creating a Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
pipe = Pipeline(steps=[
    ('scale',StandardScaler()),
    ('poly',PolynomialFeatures(include_bias=False)),
    ('model',LinearRegression())])
pipe

# %%
z = z.astype(float)
pipe.fit(z,y)

# %%
ypipe = pipe.predict(z)
print(y[0:5])
print(mean_absolute_error(y,ypipe))
ypipe[0:5]

# %%
sns.regplot(y,ypipe)

# %% [markdown]
# ### R-squared

# %%
lm.fit(z[['horsepower']],y)
print(lm.score(z[['horsepower']],y))
mean_absolute_error(lm.predict(z[['horsepower']]),y)

# %%
lm.fit(z[['curb-weight']],y)
print(lm.score(z[['curb-weight']],y))

# %%
preds = lm.predict(z[['curb-weight']])

# %%
mean_absolute_error(preds,y)

# %%
lm.fit(z,y)

# %%
from sklearn.metrics import mean_squared_error

# %%
preds = lm.predict(z)
print(lm.score(z,y))
print(mean_squared_error(preds,y))

# %% [markdown]
# ### Polyfit

# %%
from sklearn.metrics import r2_score

# %%
r_square = r2_score(y,p(x))
r_square

# %%
mean_squared_error(y,p(x))

# %% [markdown]
# ### Prediction and Decission making...

# %%
new_input = np.arange(1,100,1).reshape(-1,1)

# %%
lm.fit(x,y)

# %%
preds = lm.predict(new_input)

# %%
plt.plot(new_input,preds)
